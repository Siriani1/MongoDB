# %%
import pymongo
import pandas as pd
import certifi
#!pip install dnspython
client = pymongo.MongoClient("mongodb+srv://sirio:WlLryCFHOXnBKMbx@cluster0.jlysa.mongodb.net/sample_airbnb?retryWrites=true&w=majority", tlsCAFile=certifi.where())
db = client.sample_airbnb
doc = db.listingsAndReviews.find_one()
doc
# Out:
# {'_id': '10006546',
#  'listing_url': 'https://www.airbnb.com/rooms/10006546',
#  'name': 'Ribeira Charming Duplex',
#  'summary': 'Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.',
# ...

# %%
df1 = pd.DataFrame(list(db.listingsAndReviews.find()))
df1.head(2)
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
#
#                            name  \
# 0       Ribeira Charming Duplex
# 1  Horto flat with small garden
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
# 1  Lovely one bedroom + sofa-bed in the living ro...
#
#                                          description  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
# 1  This charming ground floor flat is located in ...
#
# ...

# %%
# gli appartamenti che costano più di 100 $ a notte
df = pd.DataFrame(list(db.listingsAndReviews.find({'price': {'$gt': 100}})))
df
# Out:
#            _id                            listing_url  \
# 0     10009999  https://www.airbnb.com/rooms/10009999
# 1      1001265   https://www.airbnb.com/rooms/1001265
# 2     10030955  https://www.airbnb.com/rooms/10030955
# 3      1003530   https://www.airbnb.com/rooms/1003530
# 4     10038496  https://www.airbnb.com/rooms/10038496
# ...        ...                                    ...
# 3242   9981541   https://www.airbnb.com/rooms/9981541
# 3243   9985696   https://www.airbnb.com/rooms/9985696
# 3244   9987200   https://www.airbnb.com/rooms/9987200
# 3245   9990304   https://www.airbnb.com/rooms/9990304
# 3246   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0                          Horto flat with small garden
# 1                      Ocean View Waikiki Marina w/prkg
# 2                           Apt Linda Vista Lagoa - Rio
# 3                   New York City - Upper West Side Apt
# ...

# %%
# gli appartamenti che costano tra i 100 $ e i 200 $ a notte

df = pd.DataFrame(list(db.listingsAndReviews.find({'price': {'$gt': 100, '$lt': 200}})))
df
# Out:
#            _id                            listing_url  \
# 0      1001265   https://www.airbnb.com/rooms/1001265
# 1      1003530   https://www.airbnb.com/rooms/1003530
# 2     10038496  https://www.airbnb.com/rooms/10038496
# 3     10066928  https://www.airbnb.com/rooms/10066928
# 4     10084023  https://www.airbnb.com/rooms/10084023
# ...        ...                                    ...
# 1321   9834391   https://www.airbnb.com/rooms/9834391
# 1322   9848595   https://www.airbnb.com/rooms/9848595
# 1323   9867316   https://www.airbnb.com/rooms/9867316
# 1324   9951865   https://www.airbnb.com/rooms/9951865
# 1325   9987200   https://www.airbnb.com/rooms/9987200
#
#                                                   name  \
# 0                     Ocean View Waikiki Marina w/prkg
# 1                  New York City - Upper West Side Apt
# 2                         Copacabana Apartment Posto 6
# 3                       3 chambres au coeur du Plateau
# ...

# %%
# gli appartamenti che hanno almeno 5 posti letto e che costano tra i 50 $ e 100 $ a notte
df = pd.DataFrame(list(db.listingsAndReviews.find({'beds': {'$gt': 4},'price': {'$gt': 50, '$lt': 100}})))
df
# Out:
#          _id                            listing_url  \
# 0   10006546  https://www.airbnb.com/rooms/10006546
# 1    1111410   https://www.airbnb.com/rooms/1111410
# 2   11413023  https://www.airbnb.com/rooms/11413023
# 3   13372754  https://www.airbnb.com/rooms/13372754
# 4   13841305  https://www.airbnb.com/rooms/13841305
# 5   14234741  https://www.airbnb.com/rooms/14234741
# 6    1437251   https://www.airbnb.com/rooms/1437251
# 7   15139440  https://www.airbnb.com/rooms/15139440
# 8   15650737  https://www.airbnb.com/rooms/15650737
# 9   15762813  https://www.airbnb.com/rooms/15762813
# 10  16147485  https://www.airbnb.com/rooms/16147485
# 11  19246639  https://www.airbnb.com/rooms/19246639
# 12  19380085  https://www.airbnb.com/rooms/19380085
# 13  19536693  https://www.airbnb.com/rooms/19536693
# 14  19592028  https://www.airbnb.com/rooms/19592028
# 15  19779206  https://www.airbnb.com/rooms/19779206
# 16  19847790  https://www.airbnb.com/rooms/19847790
# ...

# %%
# gli appartamenti in Portogallo
df = pd.DataFrame(list(db.listingsAndReviews.find({'address.country': 'Portugal'})))
df
# Out:
#           _id                            listing_url  \
# 0    10006546  https://www.airbnb.com/rooms/10006546
# 1    10083468  https://www.airbnb.com/rooms/10083468
# 2    10112159  https://www.airbnb.com/rooms/10112159
# 3    10117617  https://www.airbnb.com/rooms/10117617
# 4    10269320  https://www.airbnb.com/rooms/10269320
# ..        ...                                    ...
# 550   9280084   https://www.airbnb.com/rooms/9280084
# 551   9379065   https://www.airbnb.com/rooms/9379065
# 552   9917859   https://www.airbnb.com/rooms/9917859
# 553   9969335   https://www.airbnb.com/rooms/9969335
# 554   9983221   https://www.airbnb.com/rooms/9983221
#
#                                     name  \
# 0                Ribeira Charming Duplex
# 1                      Be Happy in Porto
# 2    Downtown Oporto Inn (room cleaning)
# 3     A Casa Alegre é um apartamento T1.
# 4                         FloresRooms 3T
# ..                                   ...
# ...

# %%
# gli appartamenti che non si trovano in Portogallo e in Spagna
df = pd.DataFrame(list(db.listingsAndReviews.find({'address.country': {'$nin': ['Portugal', 'Spain']}})))
df
